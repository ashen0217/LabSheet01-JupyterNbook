# %%
import pandas as pd
import numpy as np
from apyori import apriori

# %%
air_flightData = pd.read_csv("airlines_flights_data.csv")

# %%
print("Airline Data:",air_flightData.shape)
# Out:
# Airline Data: (300153, 12)

# %%
air_flightData.head()
# Out:
#    index   airline   flight source_city departure_time stops   arrival_time  \
# 0      0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1      1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2      2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3      3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4      4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# 2           Mumbai  Economy      2.17          1   5956
# 3           Mumbai  Economy      2.25          1   5955
# 4           Mumbai  Economy      2.33          1   5955

# %%
air_flightData.dtypes
# Out:
# index                 int64
# airline              object
# flight               object
# source_city          object
# departure_time       object
# stops                object
# arrival_time         object
# destination_city     object
# class                object
# duration            float64
# days_left             int64
# price                 int64
# dtype: object

# %%
records = []
for i in range(1,8785):
    records.append([str(air_flightData.values[i,j]) for j in range(0,7)])

display(records)

# %%
# Extract first 8784 rows and first 7 columns
records = air_flightData.iloc[1:8785, :7].astype(str).values.tolist()

# Display the records (use display() if you're in a notebook)
for record in records:
    print(record)
# Out:
# ['1', 'SpiceJet', 'SG-8157', 'Delhi', 'Early_Morning', 'zero', 'Morning']
# ['2', 'AirAsia', 'I5-764', 'Delhi', 'Early_Morning', 'zero', 'Early_Morning']
# ['3', 'Vistara', 'UK-995', 'Delhi', 'Morning', 'zero', 'Afternoon']
# ['4', 'Vistara', 'UK-963', 'Delhi', 'Morning', 'zero', 'Morning']
# ['5', 'Vistara', 'UK-945', 'Delhi', 'Morning', 'zero', 'Afternoon']
# ['6', 'Vistara', 'UK-927', 'Delhi', 'Morning', 'zero', 'Morning']
# ['7', 'Vistara', 'UK-951', 'Delhi', 'Afternoon', 'zero', 'Evening']
# ['8', 'GO_FIRST', 'G8-334', 'Delhi', 'Early_Morning', 'zero', 'Morning']
# ['9', 'GO_FIRST', 'G8-336', 'Delhi', 'Afternoon', 'zero', 'Evening']
# ['10', 'GO_FIRST', 'G8-392', 'Delhi', 'Afternoon', 'zero', 'Evening']
# ['11', 'GO_FIRST', 'G8-338', 'Delhi', 'Morning', 'zero', 'Afternoon']
# ['12', 'Indigo', '6E-5001', 'Delhi', 'Early_Morning', 'zero', 'Morning']
# ['13', 'Indigo', '6E-6202', 'Delhi', 'Morning', 'zero', 'Afternoon']
# ['14', 'Indigo', '6E-549', 'Delhi', 'Afternoon', 'zero', 'Evening']
# ['15', 'Indigo', '6E-6278', 'Delhi', 'Morning', 'zero', 'Morning']
# ['16', 'Air_India', 'AI-887', 'Delhi', 'Early_Morning', 'zero', 'Morning']
# ['17', 'Air_India', 'AI-665', 'Delhi', 'Early_Morning', 'zero', 'Morning']
# ['18', 'AirAsia', 'I5-747', 'Delhi', 'Evening', 'one', 'Early_Morning']
# ['19', 'AirAsia', 'I5-747', 'Delhi', 'Evening', 'one', 'Morning']
# ['20', 'GO_FIRST', 'G8-266', 'Delhi', 'Early_Morning', 'one', 'Evening']
# ['21', 'GO_FIRST', 'G8-101', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['22', 'GO_FIRST', 'G8-103', 'Delhi', 'Evening', 'one', 'Morning']
# ['23', 'Air_India', 'AI-441', 'Delhi', 'Evening', 'one', 'Night']
# ['24', 'Indigo', '6E-5328', 'Delhi', 'Morning', 'zero', 'Morning']
# ['25', 'Vistara', 'UK-933', 'Delhi', 'Afternoon', 'zero', 'Evening']
# ['26', 'Indigo', '6E-2046', 'Delhi', 'Evening', 'zero', 'Evening']
# ['27', 'AirAsia', 'I5-744', 'Delhi', 'Morning', 'one', 'Afternoon']
# ['28', 'SpiceJet', 'SG-8169', 'Delhi', 'Evening', 'zero', 'Night']
# ['29', 'Indigo', '6E-5041', 'Delhi', 'Evening', 'zero', 'Night']
# ['30', 'GO_FIRST', 'G8-165', 'Delhi', 'Early_Morning', 'one', 'Afternoon']
# ['31', 'Indigo', '6E-2373', 'Delhi', 'Afternoon', 'one', 'Evening']
# ['32', 'Vistara', 'UK-813', 'Delhi', 'Evening', 'one', 'Morning']
# ['33', 'Vistara', 'UK-817', 'Delhi', 'Evening', 'one', 'Morning']
# ['34', 'Vistara', 'UK-819', 'Delhi', 'Afternoon', 'one', 'Morning']
# ['35', 'Vistara', 'UK-801', 'Delhi', 'Morning', 'one', 'Morning']
# ['36', 'Vistara', 'UK-815', 'Delhi', 'Morning', 'one', 'Morning']
# ['37', 'Air_India', 'AI-453', 'Delhi', 'Early_Morning', 'one', 'Afternoon']
# ['38', 'SpiceJet', 'SG-2976', 'Delhi', 'Evening', 'one', 'Night']
# ['39', 'SpiceJet', 'SG-2976', 'Delhi', 'Evening', 'one', 'Morning']
# ['40', 'Air_India', 'AI-504', 'Delhi', 'Night', 'one', 'Morning']
# ['41', 'Air_India', 'AI-502', 'Delhi', 'Afternoon', 'one', 'Morning']
# ['42', 'Air_India', 'AI-506', 'Delhi', 'Morning', 'one', 'Morning']
# ['43', 'Air_India', 'AI-803', 'Delhi', 'Early_Morning', 'one', 'Morning']
# ['44', 'Air_India', 'AI-479', 'Delhi', 'Night', 'one', 'Afternoon']
# ['45', 'SpiceJet', 'SG-339', 'Delhi', 'Evening', 'one', 'Afternoon']
# ['46', 'Vistara', 'UK-955', 'Delhi', 'Evening', 'zero', 'Night']
# ['47', 'Vistara', 'UK-627', 'Delhi', 'Afternoon', 'one', 'Afternoon']
# ['48', 'AirAsia', 'I5-784', 'Delhi', 'Evening', 'one', 'Early_Morning']
# ['49', 'Air_India', 'AI-9643', 'Delhi', 'Evening', 'one', 'Afternoon']
# ['50', 'Air_India', 'AI-540', 'Delhi', 'Night', 'one', 'Morning']
# ['51', 'Air_India', 'AI-429', 'Delhi', 'Morning', 'one', 'Morning']
# ['52', 'Air_India', 'AI-439', 'Delhi', 'Early_Morning', 'one', 'Morning']
# ['53', 'Air_India', 'AI-9645', 'Delhi', 'Afternoon', 'one', 'Afternoon']
# ['54', 'Indigo', '6E-2193', 'Delhi', 'Afternoon', 'one', 'Evening']
# ['55', 'Indigo', '6E-2168', 'Delhi', 'Evening', 'one', 'Night']
# ['56', 'Indigo', '6.00E-152', 'Delhi', 'Morning', 'one', 'Evening']
# ['57', 'Indigo', '6E-2193', 'Delhi', 'Afternoon', 'one', 'Night']
# ['58', 'Indigo', '6E-369', 'Delhi', 'Night', 'one', 'Morning']
# ['59', 'Vistara', 'UK-899', 'Delhi', 'Afternoon', 'one', 'Afternoon']
# ['60', 'Air_India', 'AI-764', 'Delhi', 'Evening', 'one', 'Afternoon']
# ['61', 'Vistara', 'UK-747', 'Delhi', 'Early_Morning', 'one', 'Afternoon']
# ['62', 'Vistara', 'UK-809', 'Delhi', 'Evening', 'one', 'Morning']
# ['63', 'Vistara', 'UK-737', 'Delhi', 'Afternoon', 'one', 'Afternoon']
# ['64', 'Vistara', 'UK-813', 'Delhi', 'Evening', 'one', 'Night']
# ['65', 'Vistara', 'UK-817', 'Delhi', 'Evening', 'one', 'Night']
# ['66', 'Vistara', 'UK-813', 'Delhi', 'Evening', 'one', 'Night']
# ['67', 'Indigo', '6E-2338', 'Delhi', 'Afternoon', 'one', 'Night']
# ['68', 'GO_FIRST', 'G8-237', 'Delhi', 'Afternoon', 'one', 'Night']
# ['69', 'Vistara', 'UK-871', 'Delhi', 'Night', 'one', 'Afternoon']
# ['70', 'Vistara', 'UK-871', 'Delhi', 'Night', 'one', 'Night']
# ['71', 'Air_India', 'AI-762', 'Delhi', 'Night', 'one', 'Afternoon']
# ['72', 'GO_FIRST', 'G8-1404', 'Delhi', 'Morning', 'one', 'Evening']
# ['73', 'Vistara', 'UK-747', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['74', 'Air_India', 'AI-512', 'Delhi', 'Afternoon', 'one', 'Night']
# ['75', 'Air_India', 'AI-537', 'Delhi', 'Evening', 'one', 'Morning']
# ['76', 'Vistara', 'UK-977', 'Delhi', 'Evening', 'zero', 'Night']
# ['77', 'Vistara', 'UK-809', 'Delhi', 'Evening', 'one', 'Night']
# ['78', 'Vistara', 'UK-809', 'Delhi', 'Evening', 'one', 'Night']
# ['79', 'Indigo', '6.00E-184', 'Delhi', 'Morning', 'one', 'Afternoon']
# ['80', 'SpiceJet', 'SG-3002', 'Delhi', 'Early_Morning', 'one', 'Morning']
# ['81', 'Indigo', '6E-2102', 'Delhi', 'Early_Morning', 'one', 'Afternoon']
# ['82', 'Air_India', 'AI-801', 'Delhi', 'Evening', 'one', 'Night']
# ['83', 'Vistara', 'UK-637', 'Delhi', 'Evening', 'one', 'Night']
# ['84', 'Vistara', 'UK-747', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['85', 'Vistara', 'UK-835', 'Delhi', 'Evening', 'one', 'Night']
# ['86', 'Air_India', 'AI-764', 'Delhi', 'Evening', 'one', 'Night']
# ['87', 'Air_India', 'AI-531', 'Delhi', 'Evening', 'one', 'Night']
# ['88', 'Vistara', 'UK-817', 'Delhi', 'Evening', 'one', 'Night']
# ['89', 'Vistara', 'UK-819', 'Delhi', 'Afternoon', 'one', 'Night']
# ['90', 'Vistara', 'UK-801', 'Delhi', 'Morning', 'one', 'Night']
# ['91', 'Vistara', 'UK-815', 'Delhi', 'Morning', 'one', 'Night']
# ['92', 'Vistara', 'UK-813', 'Delhi', 'Evening', 'one', 'Morning']
# ['93', 'Vistara', 'UK-705', 'Delhi', 'Early_Morning', 'one', 'Afternoon']
# ['94', 'Vistara', 'UK-707', 'Delhi', 'Evening', 'one', 'Afternoon']
# ['95', 'Vistara', 'UK-737', 'Delhi', 'Afternoon', 'one', 'Night']
# ['96', 'Air_India', 'AI-762', 'Delhi', 'Night', 'one', 'Night']
# ['97', 'Vistara', 'UK-673', 'Delhi', 'Afternoon', 'one', 'Evening']
# ['98', 'Air_India', 'AI-839', 'Delhi', 'Night', 'one', 'Night']
# ['99', 'Vistara', 'UK-879', 'Delhi', 'Evening', 'one', 'Afternoon']
# ['100', 'Vistara', 'UK-705', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['101', 'GO_FIRST', 'G8-191', 'Delhi', 'Morning', 'one', 'Evening']
# ['102', 'Vistara', 'UK-819', 'Delhi', 'Afternoon', 'one', 'Night']
# ['103', 'Vistara', 'UK-801', 'Delhi', 'Morning', 'one', 'Night']
# ['104', 'Vistara', 'UK-815', 'Delhi', 'Morning', 'one', 'Night']
# ['105', 'Vistara', 'UK-809', 'Delhi', 'Evening', 'one', 'Morning']
# ['106', 'Vistara', 'UK-835', 'Delhi', 'Evening', 'one', 'Morning']
# ['107', 'Air_India', 'AI-767', 'Delhi', 'Afternoon', 'one', 'Night']
# ['108', 'Air_India', 'AI-401', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['109', 'Vistara', 'UK-705', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['110', 'Air_India', 'AI-473', 'Delhi', 'Evening', 'one', 'Evening']
# ['111', 'Vistara', 'UK-707', 'Delhi', 'Evening', 'one', 'Night']
# ['112', 'GO_FIRST', 'G8-213', 'Delhi', 'Morning', 'one', 'Evening']
# ['113', 'Air_India', 'AI-409', 'Delhi', 'Morning', 'one', 'Evening']
# ['114', 'Air_India', 'AI-429', 'Delhi', 'Morning', 'one', 'Afternoon']
# ['115', 'Air_India', 'AI-401', 'Delhi', 'Early_Morning', 'one', 'Evening']
# ['116', 'Vistara', 'UK-837', 'Delhi', 'Evening', 'one', 'Morning']
# ['117', 'Air_India', 'AI-877', 'Delhi', 'Morning', 'one', 'Evening']
# ['118', 'SpiceJet', 'SG-8803', 'Delhi', 'Early_Morning', 'zero', 'Morning']
# ['119', 'SpiceJet', 'SG-8169', 'Delhi', 'Evening', 'zero', 'Night']
# ['120', 'Vistara', 'UK-927', 'Delhi', 'Morning', 'zero', 'Morning']
# ['121', 'Vistara', 'UK-985', 'Delhi', 'Evening', 'zero', 'Night']
# ['122', 'Vistara', 'UK-977', 'Delhi', 'Evening', 'zero', 'Night']
# ['123', 'Vistara', 'UK-963', 'Delhi', 'Morning', 'zero', 'Morning']
# ['124', 'Vistara', 'UK-955', 'Delhi', 'Evening', 'zero', 'Night']
# ['125', 'Vistara', 'UK-953', 'Delhi', 'Night', 'zero', 'Night']
# ['126', 'GO_FIRST', 'G8-334', 'Delhi', 'Early_Morning', 'zero', 'Morning']
# ['127', 'GO_FIRST', 'G8-336', 'Delhi', 'Afternoon', 'zero', 'Evening']
# ['128', 'GO_FIRST', 'G8-346', 'Delhi', 'Evening', 'zero', 'Night']
# ['129', 'GO_FIRST', 'G8-330', 'Delhi', 'Night', 'zero', 'Night']
# ['130', 'GO_FIRST', 'G8-338', 'Delhi', 'Morning', 'zero', 'Afternoon']
# ['131', 'GO_FIRST', 'G8-323', 'Delhi', 'Evening', 'zero', 'Night']
# ['132', 'Indigo', '6E-5001', 'Delhi', 'Early_Morning', 'zero', 'Morning']
# ['133', 'Indigo', '6E-2046', 'Delhi', 'Evening', 'zero', 'Evening']
# ['134', 'Indigo', '6E-5041', 'Delhi', 'Evening', 'zero', 'Night']
# ['135', 'Indigo', '6.00E-218', 'Delhi', 'Morning', 'zero', 'Afternoon']
# ['136', 'Indigo', '6E-549', 'Delhi', 'Afternoon', 'zero', 'Evening']
# ['137', 'Indigo', '6E-6722', 'Delhi', 'Night', 'zero', 'Night']
# ['138', 'SpiceJet', 'SG-8157', 'Delhi', 'Early_Morning', 'zero', 'Morning']
# ['139', 'Indigo', '6E-6278', 'Delhi', 'Morning', 'zero', 'Morning']
# ['140', 'Indigo', '6E-5328', 'Delhi', 'Morning', 'zero', 'Morning']
# ['141', 'AirAsia', 'I5-764', 'Delhi', 'Early_Morning', 'zero', 'Early_Morning']
# ['142', 'Air_India', 'AI-868', 'Delhi', 'Evening', 'zero', 'Evening']
# ['143', 'Air_India', 'AI-887', 'Delhi', 'Early_Morning', 'zero', 'Morning']
# ['144', 'Air_India', 'AI-665', 'Delhi', 'Early_Morning', 'zero', 'Morning']
# ['145', 'Air_India', 'AI-805', 'Delhi', 'Evening', 'zero', 'Night']
# ['146', 'Air_India', 'AI-624', 'Delhi', 'Evening', 'zero', 'Night']
# ['147', 'AirAsia', 'I5-747', 'Delhi', 'Evening', 'one', 'Early_Morning']
# ['148', 'AirAsia', 'I5-747', 'Delhi', 'Evening', 'one', 'Morning']
# ['149', 'GO_FIRST', 'G8-188', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['150', 'GO_FIRST', 'G8-103', 'Delhi', 'Evening', 'one', 'Early_Morning']
# ['151', 'Air_India', 'AI-636', 'Delhi', 'Afternoon', 'one', 'Evening']
# ['152', 'Air_India', 'AI-441', 'Delhi', 'Evening', 'one', 'Night']
# ['153', 'Vistara', 'UK-995', 'Delhi', 'Morning', 'zero', 'Afternoon']
# ['154', 'Vistara', 'UK-951', 'Delhi', 'Afternoon', 'zero', 'Evening']
# ['155', 'Vistara', 'UK-933', 'Delhi', 'Afternoon', 'zero', 'Evening']
# ['156', 'Vistara', 'UK-945', 'Delhi', 'Morning', 'zero', 'Afternoon']
# ['157', 'AirAsia', 'I5-784', 'Delhi', 'Evening', 'one', 'Early_Morning']
# ['158', 'Indigo', '6E-6202', 'Delhi', 'Morning', 'zero', 'Afternoon']
# ['159', 'Indigo', '6E-2022', 'Delhi', 'Early_Morning', 'one', 'Evening']
# ['160', 'SpiceJet', 'SG-2976', 'Delhi', 'Evening', 'one', 'Night']
# ['161', 'SpiceJet', 'SG-2976', 'Delhi', 'Evening', 'one', 'Morning']
# ['162', 'Air_India', 'AI-469', 'Delhi', 'Early_Morning', 'one', 'Afternoon']
# ['163', 'Air_India', 'AI-542', 'Delhi', 'Morning', 'one', 'Night']
# ['164', 'Air_India', 'AI-560', 'Delhi', 'Morning', 'one', 'Night']
# ['165', 'Vistara', 'UK-683', 'Delhi', 'Afternoon', 'one', 'Afternoon']
# ['166', 'Air_India', 'AI-403', 'Delhi', 'Afternoon', 'one', 'Evening']
# ['167', 'Indigo', '6E-2154', 'Delhi', 'Morning', 'one', 'Afternoon']
# ['168', 'Air_India', 'AI-9843', 'Delhi', 'Early_Morning', 'one', 'Afternoon']
# ['169', 'Vistara', 'UK-871', 'Delhi', 'Night', 'one', 'Night']
# ['170', 'Indigo', '6E-2168', 'Delhi', 'Evening', 'one', 'Night']
# ['171', 'Indigo', '6E-2193', 'Delhi', 'Afternoon', 'one', 'Night']
# ['172', 'Indigo', '6E-369', 'Delhi', 'Night', 'one', 'Morning']
# ['173', 'Air_India', 'AI-544', 'Delhi', 'Evening', 'one', 'Night']
# ['174', 'Indigo', '6E-2338', 'Delhi', 'Afternoon', 'one', 'Night']
# ['175', 'Indigo', '6.00E-282', 'Delhi', 'Morning', 'two_or_more', 'Evening']
# ['176', 'Vistara', 'UK-809', 'Delhi', 'Evening', 'one', 'Morning']
# ['177', 'Vistara', 'UK-813', 'Delhi', 'Evening', 'one', 'Morning']
# ['178', 'Vistara', 'UK-817', 'Delhi', 'Evening', 'one', 'Morning']
# ['179', 'Vistara', 'UK-815', 'Delhi', 'Morning', 'one', 'Morning']
# ['180', 'Indigo', '6E-2193', 'Delhi', 'Afternoon', 'one', 'Evening']
# ['181', 'Indigo', '6.00E-152', 'Delhi', 'Morning', 'one', 'Evening']
# ['182', 'Air_India', 'AI-453', 'Delhi', 'Early_Morning', 'one', 'Afternoon']
# ['183', 'Vistara', 'UK-859', 'Delhi', 'Morning', 'one', 'Night']
# ['184', 'Vistara', 'UK-637', 'Delhi', 'Evening', 'one', 'Night']
# ['185', 'Vistara', 'UK-801', 'Delhi', 'Morning', 'one', 'Morning']
# ['186', 'Vistara', 'UK-829', 'Delhi', 'Early_Morning', 'one', 'Afternoon']
# ['187', 'Vistara', 'UK-899', 'Delhi', 'Afternoon', 'one', 'Night']
# ['188', 'Vistara', 'UK-829', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['189', 'Air_India', 'AI-9857', 'Delhi', 'Early_Morning', 'one', 'Afternoon']
# ['190', 'Indigo', '6E-607', 'Delhi', 'Night', 'one', 'Morning']
# ['191', 'Air_India', 'AI-504', 'Delhi', 'Night', 'one', 'Night']
# ['192', 'Vistara', 'UK-819', 'Delhi', 'Afternoon', 'one', 'Morning']
# ['193', 'Air_India', 'AI-885', 'Delhi', 'Morning', 'one', 'Late_Night']
# ['194', 'SpiceJet', 'SG-2277', 'Delhi', 'Afternoon', 'one', 'Evening']
# ['195', 'Air_India', 'AI-540', 'Delhi', 'Night', 'one', 'Morning']
# ['196', 'Air_India', 'AI-885', 'Delhi', 'Morning', 'one', 'Night']
# ['197', 'Air_India', 'AI-762', 'Delhi', 'Night', 'one', 'Afternoon']
# ['198', 'Air_India', 'AI-764', 'Delhi', 'Evening', 'one', 'Afternoon']
# ['199', 'Air_India', 'AI-885', 'Delhi', 'Morning', 'one', 'Morning']
# ['200', 'GO_FIRST', 'G8-719', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['201', 'GO_FIRST', 'G8-188', 'Delhi', 'Early_Morning', 'one', 'Afternoon']
# ['202', 'Vistara', 'UK-879', 'Delhi', 'Evening', 'one', 'Night']
# ['203', 'Vistara', 'UK-737', 'Delhi', 'Afternoon', 'one', 'Afternoon']
# ['204', 'Vistara', 'UK-817', 'Delhi', 'Evening', 'one', 'Night']
# ['205', 'Vistara', 'UK-815', 'Delhi', 'Morning', 'one', 'Night']
# ['206', 'Vistara', 'UK-815', 'Delhi', 'Morning', 'one', 'Night']
# ['207', 'Air_India', 'AI-537', 'Delhi', 'Evening', 'one', 'Morning']
# ['208', 'GO_FIRST', 'G8-266', 'Delhi', 'Early_Morning', 'one', 'Evening']
# ['209', 'Vistara', 'UK-801', 'Delhi', 'Morning', 'one', 'Night']
# ['210', 'Vistara', 'UK-801', 'Delhi', 'Morning', 'one', 'Night']
# ['211', 'Air_India', 'AI-885', 'Delhi', 'Morning', 'one', 'Evening']
# ['212', 'GO_FIRST', 'G8-119', 'Delhi', 'Evening', 'one', 'Morning']
# ['213', 'GO_FIRST', 'G8-717', 'Delhi', 'Evening', 'one', 'Night']
# ['214', 'Vistara', 'UK-819', 'Delhi', 'Afternoon', 'one', 'Night']
# ['215', 'Vistara', 'UK-819', 'Delhi', 'Afternoon', 'one', 'Night']
# ['216', 'Vistara', 'UK-706', 'Delhi', 'Afternoon', 'one', 'Night']
# ['217', 'Vistara', 'UK-809', 'Delhi', 'Evening', 'one', 'Morning']
# ['218', 'Vistara', 'UK-813', 'Delhi', 'Evening', 'one', 'Morning']
# ['219', 'Vistara', 'UK-817', 'Delhi', 'Evening', 'one', 'Morning']
# ['220', 'Vistara', 'UK-809', 'Delhi', 'Evening', 'one', 'Night']
# ['221', 'Vistara', 'UK-813', 'Delhi', 'Evening', 'one', 'Night']
# ['222', 'GO_FIRST', 'G8-1404', 'Delhi', 'Morning', 'one', 'Evening']
# ['223', 'Air_India', 'AI-439', 'Delhi', 'Early_Morning', 'one', 'Morning']
# ['224', 'Indigo', '6E-2102', 'Delhi', 'Early_Morning', 'one', 'Afternoon']
# ['225', 'Air_India', 'AI-465', 'Delhi', 'Evening', 'one', 'Night']
# ['226', 'Indigo', '6.00E-184', 'Delhi', 'Morning', 'one', 'Afternoon']
# ['227', 'SpiceJet', 'SG-3002', 'Delhi', 'Early_Morning', 'one', 'Morning']
# ['228', 'Indigo', '6E-5018', 'Delhi', 'Afternoon', 'one', 'Night']
# ['229', 'Air_India', 'AI-401', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['230', 'Vistara', 'UK-839', 'Delhi', 'Afternoon', 'one', 'Night']
# ['231', 'Vistara', 'UK-833', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['232', 'GO_FIRST', 'G8-165', 'Delhi', 'Early_Morning', 'one', 'Afternoon']
# ['233', 'Vistara', 'UK-809', 'Delhi', 'Evening', 'one', 'Night']
# ['234', 'Vistara', 'UK-813', 'Delhi', 'Evening', 'one', 'Night']
# ['235', 'GO_FIRST', 'G8-237', 'Delhi', 'Afternoon', 'one', 'Night']
# ['236', 'Air_India', 'AI-762', 'Delhi', 'Night', 'one', 'Night']
# ['237', 'Air_India', 'AI-764', 'Delhi', 'Evening', 'one', 'Night']
# ['238', 'Vistara', 'UK-673', 'Delhi', 'Afternoon', 'one', 'Evening']
# ['239', 'Vistara', 'UK-627', 'Delhi', 'Afternoon', 'one', 'Afternoon']
# ['240', 'Vistara', 'UK-705', 'Delhi', 'Early_Morning', 'one', 'Afternoon']
# ['241', 'Air_India', 'AI-406', 'Delhi', 'Morning', 'one', 'Afternoon']
# ['242', 'Air_India', 'AI-9809', 'Delhi', 'Afternoon', 'one', 'Afternoon']
# ['243', 'Air_India', 'AI-512', 'Delhi', 'Afternoon', 'one', 'Night']
# ['244', 'GO_FIRST', 'G8-286', 'Delhi', 'Morning', 'one', 'Evening']
# ['245', 'GO_FIRST', 'G8-286', 'Delhi', 'Morning', 'one', 'Evening']
# ['246', 'Vistara', 'UK-847', 'Delhi', 'Morning', 'one', 'Afternoon']
# ['247', 'Air_India', 'AI-411', 'Delhi', 'Early_Morning', 'one', 'Afternoon']
# ['248', 'Vistara', 'UK-737', 'Delhi', 'Afternoon', 'one', 'Night']
# ['249', 'Vistara', 'UK-705', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['250', 'Air_India', 'AI-877', 'Delhi', 'Morning', 'one', 'Evening']
# ['251', 'SpiceJet', 'SG-8803', 'Delhi', 'Early_Morning', 'zero', 'Morning']
# ['252', 'SpiceJet', 'SG-8157', 'Delhi', 'Early_Morning', 'zero', 'Morning']
# ['253', 'SpiceJet', 'SG-8169', 'Delhi', 'Evening', 'zero', 'Night']
# ['254', 'Vistara', 'UK-927', 'Delhi', 'Morning', 'zero', 'Morning']
# ['255', 'Vistara', 'UK-995', 'Delhi', 'Morning', 'zero', 'Afternoon']
# ['256', 'Vistara', 'UK-963', 'Delhi', 'Morning', 'zero', 'Morning']
# ['257', 'GO_FIRST', 'G8-334', 'Delhi', 'Early_Morning', 'zero', 'Morning']
# ['258', 'GO_FIRST', 'G8-346', 'Delhi', 'Evening', 'zero', 'Night']
# ['259', 'GO_FIRST', 'G8-338', 'Delhi', 'Morning', 'zero', 'Afternoon']
# ['260', 'GO_FIRST', 'G8-323', 'Delhi', 'Evening', 'zero', 'Night']
# ['261', 'Indigo', '6E-5001', 'Delhi', 'Early_Morning', 'zero', 'Morning']
# ['262', 'Indigo', '6.00E-218', 'Delhi', 'Morning', 'zero', 'Afternoon']
# ['263', 'Indigo', '6E-6278', 'Delhi', 'Morning', 'zero', 'Morning']
# ['264', 'Indigo', '6E-5328', 'Delhi', 'Morning', 'zero', 'Morning']
# ['265', 'AirAsia', 'I5-764', 'Delhi', 'Early_Morning', 'zero', 'Early_Morning']
# ['266', 'Air_India', 'AI-887', 'Delhi', 'Early_Morning', 'zero', 'Morning']
# ['267', 'Air_India', 'AI-665', 'Delhi', 'Early_Morning', 'zero', 'Morning']
# ['268', 'Air_India', 'AI-805', 'Delhi', 'Evening', 'zero', 'Night']
# ['269', 'Air_India', 'AI-624', 'Delhi', 'Evening', 'zero', 'Night']
# ['270', 'GO_FIRST', 'G8-103', 'Delhi', 'Evening', 'one', 'Early_Morning']
# ['271', 'GO_FIRST', 'G8-113', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['272', 'Air_India', 'AI-441', 'Delhi', 'Evening', 'one', 'Night']
# ['273', 'Vistara', 'UK-985', 'Delhi', 'Evening', 'zero', 'Night']
# ['274', 'SpiceJet', 'SG-8709', 'Delhi', 'Evening', 'zero', 'Night']
# ['275', 'SpiceJet', 'SG-8483', 'Delhi', 'Evening', 'one', 'Early_Morning']
# ['276', 'Vistara', 'UK-977', 'Delhi', 'Evening', 'zero', 'Night']
# ['277', 'GO_FIRST', 'G8-336', 'Delhi', 'Afternoon', 'zero', 'Evening']
# ['278', 'GO_FIRST', 'G8-330', 'Delhi', 'Night', 'zero', 'Night']
# ['279', 'Vistara', 'UK-945', 'Delhi', 'Morning', 'zero', 'Afternoon']
# ['280', 'Air_India', 'AI-868', 'Delhi', 'Evening', 'zero', 'Evening']
# ['281', 'GO_FIRST', 'G8-392', 'Delhi', 'Afternoon', 'zero', 'Evening']
# ['282', 'Indigo', '6E-2022', 'Delhi', 'Early_Morning', 'one', 'Evening']
# ['283', 'Indigo', '6E-2154', 'Delhi', 'Morning', 'one', 'Afternoon']
# ['284', 'Indigo', '6E-6202', 'Delhi', 'Morning', 'zero', 'Afternoon']
# ['285', 'Indigo', '6E-5041', 'Delhi', 'Evening', 'zero', 'Night']
# ['286', 'Indigo', '6E-2046', 'Delhi', 'Evening', 'zero', 'Evening']
# ['287', 'Indigo', '6E-549', 'Delhi', 'Afternoon', 'zero', 'Evening']
# ['288', 'Vistara', 'UK-933', 'Delhi', 'Afternoon', 'zero', 'Evening']
# ['289', 'Vistara', 'UK-683', 'Delhi', 'Afternoon', 'one', 'Afternoon']
# ['290', 'AirAsia', 'I5-747', 'Delhi', 'Evening', 'one', 'Early_Morning']
# ['291', 'Air_India', 'AI-475', 'Delhi', 'Afternoon', 'one', 'Afternoon']
# ['292', 'Indigo', '6E-2373', 'Delhi', 'Afternoon', 'one', 'Evening']
# ['293', 'Vistara', 'UK-829', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['294', 'SpiceJet', 'SG-2976', 'Delhi', 'Evening', 'one', 'Morning']
# ['295', 'Air_India', 'AI-531', 'Delhi', 'Evening', 'one', 'Night']
# ['296', 'GO_FIRST', 'G8-719', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['297', 'Indigo', '6E-369', 'Delhi', 'Night', 'one', 'Morning']
# ['298', 'Vistara', 'UK-871', 'Delhi', 'Night', 'one', 'Afternoon']
# ['299', 'Vistara', 'UK-879', 'Delhi', 'Evening', 'one', 'Afternoon']
# ['300', 'Vistara', 'UK-871', 'Delhi', 'Night', 'one', 'Night']
# ['301', 'Indigo', '6E-2168', 'Delhi', 'Evening', 'one', 'Night']
# ['302', 'Indigo', '6E-2193', 'Delhi', 'Afternoon', 'one', 'Night']
# ['303', 'Air_India', 'AI-9643', 'Delhi', 'Evening', 'one', 'Afternoon']
# ['304', 'Vistara', 'UK-859', 'Delhi', 'Morning', 'one', 'Night']
# ['305', 'Vistara', 'UK-815', 'Delhi', 'Morning', 'one', 'Morning']
# ['306', 'SpiceJet', 'SG-2976', 'Delhi', 'Evening', 'one', 'Night']
# ['307', 'Indigo', '6E-2193', 'Delhi', 'Afternoon', 'one', 'Evening']
# ['308', 'Indigo', '6.00E-152', 'Delhi', 'Morning', 'one', 'Evening']
# ['309', 'Air_India', 'AI-479', 'Delhi', 'Night', 'one', 'Afternoon']
# ['310', 'Indigo', '6.00E-181', 'Delhi', 'Early_Morning', 'one', 'Morning']
# ['311', 'SpiceJet', 'SG-2277', 'Delhi', 'Afternoon', 'one', 'Evening']
# ['312', 'GO_FIRST', 'G8-286', 'Delhi', 'Morning', 'two_or_more', 'Night']
# ['313', 'GO_FIRST', 'G8-119', 'Delhi', 'Evening', 'one', 'Morning']
# ['314', 'Air_India', 'AI-504', 'Delhi', 'Night', 'one', 'Morning']
# ['315', 'Air_India', 'AI-504', 'Delhi', 'Night', 'one', 'Night']
# ['316', 'Air_India', 'AI-803', 'Delhi', 'Early_Morning', 'one', 'Morning']
# ['317', 'GO_FIRST', 'G8-717', 'Delhi', 'Evening', 'one', 'Night']
# ['318', 'Vistara', 'UK-879', 'Delhi', 'Evening', 'one', 'Night']
# ['319', 'Air_India', 'AI-9645', 'Delhi', 'Afternoon', 'one', 'Afternoon']
# ['320', 'Vistara', 'UK-951', 'Delhi', 'Afternoon', 'zero', 'Evening']
# ['321', 'Air_India', 'AI-803', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['322', 'Vistara', 'UK-627', 'Delhi', 'Afternoon', 'one', 'Afternoon']
# ['323', 'Indigo', '6E-2092', 'Delhi', 'Evening', 'one', 'Night']
# ['324', 'Indigo', '6E-5018', 'Delhi', 'Afternoon', 'one', 'Night']
# ['325', 'AirAsia', 'I5-784', 'Delhi', 'Evening', 'one', 'Early_Morning']
# ['326', 'Vistara', 'UK-899', 'Delhi', 'Afternoon', 'one', 'Afternoon']
# ['327', 'GO_FIRST', 'G8-1404', 'Delhi', 'Morning', 'one', 'Afternoon']
# ['328', 'GO_FIRST', 'G8-1404', 'Delhi', 'Morning', 'one', 'Evening']
# ['329', 'Air_India', 'AI-9911', 'Delhi', 'Morning', 'one', 'Afternoon']
# ['330', 'Vistara', 'UK-801', 'Delhi', 'Morning', 'one', 'Morning']
# ['331', 'SpiceJet', 'SG-3002', 'Delhi', 'Early_Morning', 'one', 'Morning']
# ['332', 'Indigo', '6E-5063', 'Delhi', 'Afternoon', 'one', 'Night']
# ['333', 'Air_India', 'AI-411', 'Delhi', 'Early_Morning', 'one', 'Afternoon']
# ['334', 'Vistara', 'UK-809', 'Delhi', 'Evening', 'one', 'Morning']
# ['335', 'Vistara', 'UK-809', 'Delhi', 'Evening', 'one', 'Night']
# ['336', 'Vistara', 'UK-809', 'Delhi', 'Evening', 'one', 'Night']
# ['337', 'Indigo', '6E-2102', 'Delhi', 'Early_Morning', 'one', 'Afternoon']
# ['338', 'Vistara', 'UK-637', 'Delhi', 'Evening', 'one', 'Night']
# ['339', 'Vistara', 'UK-835', 'Delhi', 'Evening', 'one', 'Morning']
# ['340', 'Vistara', 'UK-835', 'Delhi', 'Evening', 'one', 'Night']
# ['341', 'Vistara', 'UK-833', 'Delhi', 'Early_Morning', 'one', 'Morning']
# ['342', 'GO_FIRST', 'G8-266', 'Delhi', 'Early_Morning', 'one', 'Evening']
# ['343', 'Air_India', 'AI-764', 'Delhi', 'Evening', 'one', 'Afternoon']
# ['344', 'Vistara', 'UK-899', 'Delhi', 'Afternoon', 'one', 'Night']
# ['345', 'Vistara', 'UK-813', 'Delhi', 'Evening', 'one', 'Morning']
# ['346', 'Vistara', 'UK-813', 'Delhi', 'Evening', 'one', 'Night']
# ['347', 'Vistara', 'UK-813', 'Delhi', 'Evening', 'one', 'Night']
# ['348', 'Indigo', '6E-2338', 'Delhi', 'Afternoon', 'one', 'Night']
# ['349', 'Vistara', 'UK-815', 'Delhi', 'Morning', 'one', 'Night']
# ['350', 'Vistara', 'UK-815', 'Delhi', 'Morning', 'one', 'Morning']
# ['351', 'Vistara', 'UK-737', 'Delhi', 'Afternoon', 'one', 'Night']
# ['352', 'Air_India', 'AI-762', 'Delhi', 'Night', 'one', 'Afternoon']
# ['353', 'Indigo', '6E-7403', 'Delhi', 'Early_Morning', 'one', 'Evening']
# ['354', 'Indigo', '6E-607', 'Delhi', 'Night', 'one', 'Morning']
# ['355', 'Vistara', 'UK-953', 'Delhi', 'Night', 'zero', 'Night']
# ['356', 'Vistara', 'UK-955', 'Delhi', 'Evening', 'zero', 'Night']
# ['357', 'Air_India', 'AI-429', 'Delhi', 'Morning', 'one', 'Afternoon']
# ['358', 'Indigo', '6E-6722', 'Delhi', 'Night', 'zero', 'Night']
# ['359', 'Indigo', '6.00E-184', 'Delhi', 'Morning', 'one', 'Afternoon']
# ['360', 'Indigo', '6E-2154', 'Delhi', 'Morning', 'one', 'Evening']
# ['361', 'Air_India', 'AI-540', 'Delhi', 'Night', 'one', 'Evening']
# ['362', 'Air_India', 'AI-537', 'Delhi', 'Evening', 'one', 'Evening']
# ['363', 'Air_India', 'AI-801', 'Delhi', 'Evening', 'one', 'Night']
# ['364', 'Vistara', 'UK-855', 'Delhi', 'Evening', 'one', 'Afternoon']
# ['365', 'Vistara', 'UK-801', 'Delhi', 'Morning', 'one', 'Night']
# ['366', 'GO_FIRST', 'G8-165', 'Delhi', 'Early_Morning', 'one', 'Afternoon']
# ['367', 'Vistara', 'UK-737', 'Delhi', 'Afternoon', 'one', 'Afternoon']
# ['368', 'GO_FIRST', 'G8-191', 'Delhi', 'Morning', 'one', 'Evening']
# ['369', 'Vistara', 'UK-809', 'Delhi', 'Evening', 'one', 'Morning']
# ['370', 'Vistara', 'UK-815', 'Delhi', 'Morning', 'one', 'Night']
# ['371', 'GO_FIRST', 'G8-237', 'Delhi', 'Afternoon', 'one', 'Night']
# ['372', 'Air_India', 'AI-9843', 'Delhi', 'Early_Morning', 'one', 'Afternoon']
# ['373', 'Vistara', 'UK-813', 'Delhi', 'Evening', 'one', 'Morning']
# ['374', 'Vistara', 'UK-819', 'Delhi', 'Afternoon', 'one', 'Morning']
# ['375', 'Vistara', 'UK-837', 'Delhi', 'Evening', 'one', 'Morning']
# ['376', 'Air_India', 'AI-401', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['377', 'Vistara', 'UK-801', 'Delhi', 'Morning', 'one', 'Night']
# ['378', 'Vistara', 'UK-706', 'Delhi', 'Afternoon', 'one', 'Night']
# ['379', 'Air_India', 'AI-807', 'Delhi', 'Evening', 'one', 'Morning']
# ['380', 'Air_India', 'AI-502', 'Delhi', 'Afternoon', 'one', 'Morning']
# ['381', 'Air_India', 'AI-502', 'Delhi', 'Afternoon', 'one', 'Night']
# ['382', 'Vistara', 'UK-819', 'Delhi', 'Afternoon', 'one', 'Night']
# ['383', 'Vistara', 'UK-847', 'Delhi', 'Morning', 'one', 'Afternoon']
# ['384', 'GO_FIRST', 'G8-213', 'Delhi', 'Morning', 'one', 'Evening']
# ['385', 'Air_India', 'AI-506', 'Delhi', 'Morning', 'one', 'Morning']
# ['386', 'Vistara', 'UK-819', 'Delhi', 'Afternoon', 'one', 'Night']
# ['387', 'Air_India', 'AI-406', 'Delhi', 'Morning', 'one', 'Afternoon']
# ['388', 'Air_India', 'AI-506', 'Delhi', 'Morning', 'one', 'Night']
# ['389', 'GO_FIRST', 'G8-300', 'Delhi', 'Morning', 'one', 'Afternoon']
# ['390', 'Air_India', 'AI-811', 'Delhi', 'Evening', 'one', 'Afternoon']
# ['391', 'Air_India', 'AI-431', 'Delhi', 'Afternoon', 'one', 'Afternoon']
# ['392', 'Air_India', 'AI-465', 'Delhi', 'Evening', 'one', 'Night']
# ['393', 'Air_India', 'AI-9809', 'Delhi', 'Afternoon', 'one', 'Afternoon']
# ['394', 'Air_India', 'AI-764', 'Delhi', 'Evening', 'one', 'Night']
# ['395', 'Air_India', 'AI-762', 'Delhi', 'Night', 'one', 'Night']
# ['396', 'Air_India', 'AI-877', 'Delhi', 'Morning', 'one', 'Evening']
# ['397', 'Air_India', 'AI-512', 'Delhi', 'Afternoon', 'one', 'Night']
# ['398', 'SpiceJet', 'SG-8709', 'Delhi', 'Evening', 'zero', 'Night']
# ['399', 'SpiceJet', 'SG-1089', 'Delhi', 'Early_Morning', 'zero', 'Morning']
# ['400', 'SpiceJet', 'SG-1061', 'Delhi', 'Early_Morning', 'zero', 'Morning']
# ['401', 'SpiceJet', 'SG-8157', 'Delhi', 'Early_Morning', 'zero', 'Morning']
# ['402', 'SpiceJet', 'SG-1063', 'Delhi', 'Evening', 'zero', 'Night']
# ['403', 'SpiceJet', 'SG-8169', 'Delhi', 'Evening', 'zero', 'Night']
# ['404', 'Vistara', 'UK-951', 'Delhi', 'Afternoon', 'zero', 'Evening']
# ['405', 'Vistara', 'UK-933', 'Delhi', 'Afternoon', 'zero', 'Evening']
# ['406', 'Vistara', 'UK-985', 'Delhi', 'Evening', 'zero', 'Night']
# ['407', 'Vistara', 'UK-995', 'Delhi', 'Morning', 'zero', 'Afternoon']
# ['408', 'Vistara', 'UK-977', 'Delhi', 'Evening', 'zero', 'Night']
# ['409', 'Vistara', 'UK-945', 'Delhi', 'Morning', 'zero', 'Afternoon']
# ['410', 'Vistara', 'UK-955', 'Delhi', 'Evening', 'zero', 'Night']
# ['411', 'Vistara', 'UK-927', 'Delhi', 'Morning', 'zero', 'Morning']
# ['412', 'Vistara', 'UK-953', 'Delhi', 'Night', 'zero', 'Night']
# ['413', 'GO_FIRST', 'G8-336', 'Delhi', 'Afternoon', 'zero', 'Evening']
# ['414', 'GO_FIRST', 'G8-392', 'Delhi', 'Afternoon', 'zero', 'Evening']
# ['415', 'GO_FIRST', 'G8-346', 'Delhi', 'Evening', 'zero', 'Night']
# ['416', 'GO_FIRST', 'G8-330', 'Delhi', 'Night', 'zero', 'Night']
# ['417', 'GO_FIRST', 'G8-338', 'Delhi', 'Morning', 'zero', 'Afternoon']
# ['418', 'GO_FIRST', 'G8-323', 'Delhi', 'Evening', 'zero', 'Night']
# ['419', 'Indigo', '6E-2054', 'Delhi', 'Early_Morning', 'zero', 'Morning']
# ['420', 'Indigo', '6E-6202', 'Delhi', 'Morning', 'zero', 'Afternoon']
# ['421', 'Indigo', '6E-2046', 'Delhi', 'Evening', 'zero', 'Evening']
# ['422', 'Indigo', '6E-5041', 'Delhi', 'Evening', 'zero', 'Night']
# ['423', 'SpiceJet', 'SG-8803', 'Delhi', 'Early_Morning', 'zero', 'Morning']
# ['424', 'Indigo', '6.00E-218', 'Delhi', 'Morning', 'zero', 'Afternoon']
# ['425', 'Indigo', '6E-549', 'Delhi', 'Afternoon', 'zero', 'Evening']
# ['426', 'Indigo', '6E-6722', 'Delhi', 'Night', 'zero', 'Night']
# ['427', 'Indigo', '6E-6278', 'Delhi', 'Morning', 'zero', 'Morning']
# ['428', 'Indigo', '6E-5328', 'Delhi', 'Morning', 'zero', 'Morning']
# ['429', 'Air_India', 'AI-868', 'Delhi', 'Evening', 'zero', 'Evening']
# ['430', 'Air_India', 'AI-887', 'Delhi', 'Early_Morning', 'zero', 'Morning']
# ['431', 'Air_India', 'AI-665', 'Delhi', 'Early_Morning', 'zero', 'Morning']
# ['432', 'Air_India', 'AI-805', 'Delhi', 'Evening', 'zero', 'Night']
# ['433', 'Air_India', 'AI-678', 'Delhi', 'Morning', 'zero', 'Morning']
# ['434', 'Air_India', 'AI-624', 'Delhi', 'Evening', 'zero', 'Night']
# ['435', 'AirAsia', 'I5-784', 'Delhi', 'Evening', 'one', 'Early_Morning']
# ['436', 'GO_FIRST', 'G8-1010', 'Delhi', 'Afternoon', 'one', 'Evening']
# ['437', 'GO_FIRST', 'G8-191', 'Delhi', 'Morning', 'one', 'Evening']
# ['438', 'GO_FIRST', 'G8-237', 'Delhi', 'Afternoon', 'one', 'Night']
# ['439', 'GO_FIRST', 'G8-266', 'Delhi', 'Early_Morning', 'one', 'Evening']
# ['440', 'GO_FIRST', 'G8-103', 'Delhi', 'Evening', 'one', 'Early_Morning']
# ['441', 'GO_FIRST', 'G8-119', 'Delhi', 'Evening', 'one', 'Morning']
# ['442', 'GO_FIRST', 'G8-113', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['443', 'Air_India', 'AI-441', 'Delhi', 'Evening', 'one', 'Night']
# ['444', 'SpiceJet', 'SG-2976', 'Delhi', 'Evening', 'one', 'Night']
# ['445', 'Indigo', '6E-2022', 'Delhi', 'Early_Morning', 'one', 'Evening']
# ['446', 'Indigo', '6E-5018', 'Delhi', 'Afternoon', 'one', 'Night']
# ['447', 'Indigo', '6E-369', 'Delhi', 'Night', 'one', 'Morning']
# ['448', 'SpiceJet', 'SG-2976', 'Delhi', 'Evening', 'one', 'Morning']
# ['449', 'SpiceJet', 'SG-2277', 'Delhi', 'Afternoon', 'one', 'Evening']
# ['450', 'AirAsia', 'I5-764', 'Delhi', 'Early_Morning', 'zero', 'Early_Morning']
# ['451', 'Indigo', '6E-5001', 'Delhi', 'Early_Morning', 'zero', 'Morning']
# ['452', 'SpiceJet', 'SG-8483', 'Delhi', 'Evening', 'one', 'Early_Morning']
# ['453', 'Vistara', 'UK-963', 'Delhi', 'Morning', 'zero', 'Morning']
# ['454', 'Indigo', '6E-2092', 'Delhi', 'Evening', 'one', 'Night']
# ['455', 'GO_FIRST', 'G8-334', 'Delhi', 'Early_Morning', 'zero', 'Morning']
# ['456', 'Indigo', '6E-607', 'Delhi', 'Night', 'one', 'Morning']
# ['457', 'Indigo', '6E-2193', 'Delhi', 'Afternoon', 'one', 'Evening']
# ['458', 'Indigo', '6.00E-152', 'Delhi', 'Morning', 'one', 'Evening']
# ['459', 'Indigo', '6E-2193', 'Delhi', 'Afternoon', 'one', 'Night']
# ['460', 'Air_India', 'AI-435', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['461', 'Vistara', 'UK-637', 'Delhi', 'Evening', 'one', 'Morning']
# ['462', 'Vistara', 'UK-706', 'Delhi', 'Afternoon', 'one', 'Morning']
# ['463', 'Air_India', 'AI-9643', 'Delhi', 'Evening', 'one', 'Afternoon']
# ['464', 'Air_India', 'AI-499', 'Delhi', 'Afternoon', 'one', 'Afternoon']
# ['465', 'GO_FIRST', 'G8-719', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['466', 'Indigo', '6E-2338', 'Delhi', 'Afternoon', 'one', 'Night']
# ['467', 'Air_India', 'AI-9887', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['468', 'Air_India', 'AI-469', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['469', 'GO_FIRST', 'G8-717', 'Delhi', 'Evening', 'one', 'Night']
# ['470', 'Vistara', 'UK-899', 'Delhi', 'Afternoon', 'one', 'Night']
# ['471', 'Vistara', 'UK-859', 'Delhi', 'Morning', 'one', 'Night']
# ['472', 'Vistara', 'UK-871', 'Delhi', 'Night', 'one', 'Morning']
# ['473', 'Vistara', 'UK-871', 'Delhi', 'Night', 'one', 'Afternoon']
# ['474', 'Vistara', 'UK-899', 'Delhi', 'Afternoon', 'one', 'Morning']
# ['475', 'Vistara', 'UK-859', 'Delhi', 'Morning', 'one', 'Morning']
# ['476', 'Vistara', 'UK-899', 'Delhi', 'Afternoon', 'one', 'Afternoon']
# ['477', 'Vistara', 'UK-871', 'Delhi', 'Night', 'one', 'Night']
# ['478', 'Air_India', 'AI-9843', 'Delhi', 'Early_Morning', 'one', 'Afternoon']
# ['479', 'Indigo', '6E-2373', 'Delhi', 'Afternoon', 'one', 'Evening']
# ['480', 'Air_India', 'AI-483', 'Delhi', 'Evening', 'one', 'Evening']
# ['481', 'Air_India', 'AI-475', 'Delhi', 'Afternoon', 'one', 'Afternoon']
# ['482', 'Vistara', 'UK-637', 'Delhi', 'Evening', 'one', 'Night']
# ['483', 'Vistara', 'UK-879', 'Delhi', 'Evening', 'one', 'Night']
# ['484', 'Vistara', 'UK-706', 'Delhi', 'Afternoon', 'one', 'Night']
# ['485', 'Vistara', 'UK-879', 'Delhi', 'Evening', 'one', 'Morning']
# ['486', 'Vistara', 'UK-879', 'Delhi', 'Evening', 'one', 'Afternoon']
# ['487', 'Air_India', 'AI-531', 'Delhi', 'Evening', 'one', 'Night']
# ['488', 'Indigo', '6E-2168', 'Delhi', 'Evening', 'one', 'Night']
# ['489', 'Indigo', '6.00E-184', 'Delhi', 'Morning', 'one', 'Afternoon']
# ['490', 'GO_FIRST', 'G8-1404', 'Delhi', 'Morning', 'one', 'Evening']
# ['491', 'GO_FIRST', 'G8-165', 'Delhi', 'Early_Morning', 'one', 'Afternoon']
# ['492', 'Air_India', 'AI-473', 'Delhi', 'Evening', 'one', 'Evening']
# ['493', 'Vistara', 'UK-855', 'Delhi', 'Evening', 'one', 'Afternoon']
# ['494', 'Vistara', 'UK-627', 'Delhi', 'Afternoon', 'one', 'Afternoon']
# ['495', 'Vistara', 'UK-847', 'Delhi', 'Morning', 'one', 'Afternoon']
# ['496', 'GO_FIRST', 'G8-357', 'Delhi', 'Early_Morning', 'two_or_more', 'Evening']
# ['497', 'GO_FIRST', 'G8-213', 'Delhi', 'Morning', 'one', 'Evening']
# ['498', 'Vistara', 'UK-673', 'Delhi', 'Afternoon', 'one', 'Evening']
# ['499', 'Vistara', 'UK-817', 'Delhi', 'Evening', 'one', 'Night']
# ['500', 'Vistara', 'UK-819', 'Delhi', 'Afternoon', 'one', 'Night']
# ['501', 'Vistara', 'UK-819', 'Delhi', 'Afternoon', 'one', 'Night']
# ['502', 'Vistara', 'UK-801', 'Delhi', 'Morning', 'one', 'Night']
# ['503', 'Vistara', 'UK-815', 'Delhi', 'Morning', 'one', 'Night']
# ['504', 'Vistara', 'UK-809', 'Delhi', 'Evening', 'one', 'Morning']
# ['505', 'Vistara', 'UK-801', 'Delhi', 'Morning', 'one', 'Night']
# ['506', 'Vistara', 'UK-815', 'Delhi', 'Morning', 'one', 'Night']
# ['507', 'Vistara', 'UK-809', 'Delhi', 'Evening', 'one', 'Morning']
# ['508', 'Vistara', 'UK-813', 'Delhi', 'Evening', 'one', 'Morning']
# ['509', 'Vistara', 'UK-809', 'Delhi', 'Evening', 'one', 'Morning']
# ['510', 'Vistara', 'UK-817', 'Delhi', 'Evening', 'one', 'Morning']
# ['511', 'Air_India', 'AI-453', 'Delhi', 'Early_Morning', 'one', 'Afternoon']
# ['512', 'Air_India', 'AI-502', 'Delhi', 'Afternoon', 'one', 'Night']
# ['513', 'Air_India', 'AI-506', 'Delhi', 'Morning', 'one', 'Night']
# ['514', 'Air_India', 'AI-504', 'Delhi', 'Night', 'one', 'Morning']
# ['515', 'Air_India', 'AI-803', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['516', 'Air_India', 'AI-807', 'Delhi', 'Evening', 'one', 'Morning']
# ['517', 'Air_India', 'AI-502', 'Delhi', 'Afternoon', 'one', 'Morning']
# ['518', 'Air_India', 'AI-506', 'Delhi', 'Morning', 'one', 'Morning']
# ['519', 'Air_India', 'AI-803', 'Delhi', 'Early_Morning', 'one', 'Morning']
# ['520', 'SpiceJet', 'SG-339', 'Delhi', 'Afternoon', 'one', 'Afternoon']
# ['521', 'Air_India', 'AI-9857', 'Delhi', 'Early_Morning', 'one', 'Afternoon']
# ['522', 'Indigo', '6E-2102', 'Delhi', 'Early_Morning', 'one', 'Afternoon']
# ['523', 'Air_India', 'AI-451', 'Delhi', 'Afternoon', 'one', 'Evening']
# ['524', 'Indigo', '6.00E-181', 'Delhi', 'Early_Morning', 'one', 'Morning']
# ['525', 'Vistara', 'UK-737', 'Delhi', 'Afternoon', 'one', 'Night']
# ['526', 'Vistara', 'UK-835', 'Delhi', 'Evening', 'one', 'Morning']
# ['527', 'Vistara', 'UK-837', 'Delhi', 'Evening', 'one', 'Morning']
# ['528', 'Vistara', 'UK-835', 'Delhi', 'Evening', 'one', 'Afternoon']
# ['529', 'Vistara', 'UK-837', 'Delhi', 'Evening', 'one', 'Afternoon']
# ['530', 'Air_India', 'AI-540', 'Delhi', 'Night', 'one', 'Morning']
# ['531', 'Air_India', 'AI-537', 'Delhi', 'Evening', 'one', 'Morning']
# ['532', 'Air_India', 'AI-762', 'Delhi', 'Night', 'one', 'Afternoon']
# ['533', 'Air_India', 'AI-764', 'Delhi', 'Evening', 'one', 'Afternoon']
# ['534', 'Air_India', 'AI-762', 'Delhi', 'Night', 'one', 'Night']
# ['535', 'GO_FIRST', 'G8-286', 'Delhi', 'Morning', 'one', 'Evening']
# ['536', 'Vistara', 'UK-835', 'Delhi', 'Evening', 'one', 'Morning']
# ['537', 'Vistara', 'UK-837', 'Delhi', 'Evening', 'one', 'Morning']
# ['538', 'Vistara', 'UK-839', 'Delhi', 'Afternoon', 'one', 'Morning']
# ['539', 'Vistara', 'UK-833', 'Delhi', 'Early_Morning', 'one', 'Morning']
# ['540', 'SpiceJet', 'SG-3002', 'Delhi', 'Early_Morning', 'one', 'Morning']
# ['541', 'Vistara', 'UK-839', 'Delhi', 'Afternoon', 'one', 'Night']
# ['542', 'Vistara', 'UK-833', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['543', 'Air_India', 'AI-885', 'Delhi', 'Morning', 'one', 'Evening']
# ['544', 'Air_India', 'AI-885', 'Delhi', 'Morning', 'one', 'Night']
# ['545', 'Vistara', 'UK-705', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['546', 'Air_India', 'AI-429', 'Delhi', 'Morning', 'one', 'Afternoon']
# ['547', 'Air_India', 'AI-471', 'Delhi', 'Afternoon', 'one', 'Evening']
# ['548', 'Air_India', 'AI-429', 'Delhi', 'Morning', 'one', 'Evening']
# ['549', 'Air_India', 'AI-439', 'Delhi', 'Early_Morning', 'one', 'Evening']
# ['550', 'Vistara', 'UK-705', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['551', 'Vistara', 'UK-747', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['552', 'GO_FIRST', 'G8-286', 'Delhi', 'Morning', 'one', 'Evening']
# ['553', 'Vistara', 'UK-747', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['554', 'Vistara', 'UK-705', 'Delhi', 'Early_Morning', 'one', 'Afternoon']
# ['555', 'Vistara', 'UK-707', 'Delhi', 'Evening', 'one', 'Night']
# ['556', 'Vistara', 'UK-747', 'Delhi', 'Early_Morning', 'one', 'Afternoon']
# ['557', 'Air_India', 'AI-465', 'Delhi', 'Evening', 'one', 'Night']
# ['558', 'Air_India', 'AI-512', 'Delhi', 'Afternoon', 'one', 'Night']
# ['559', 'Air_India', 'AI-540', 'Delhi', 'Night', 'one', 'Evening']
# ['560', 'Air_India', 'AI-537', 'Delhi', 'Evening', 'one', 'Evening']
# ['561', 'Air_India', 'AI-406', 'Delhi', 'Morning', 'one', 'Afternoon']
# ['562', 'Air_India', 'AI-411', 'Delhi', 'Early_Morning', 'one', 'Afternoon']
# ['563', 'SpiceJet', 'SG-1091', 'Delhi', 'Evening', 'zero', 'Night']
# ['564', 'SpiceJet', 'SG-8709', 'Delhi', 'Evening', 'zero', 'Night']
# ['565', 'SpiceJet', 'SG-1089', 'Delhi', 'Early_Morning', 'zero', 'Morning']
# ['566', 'SpiceJet', 'SG-8803', 'Delhi', 'Early_Morning', 'zero', 'Morning']
# ['567', 'SpiceJet', 'SG-1061', 'Delhi', 'Early_Morning', 'zero', 'Morning']
# ['568', 'SpiceJet', 'SG-8157', 'Delhi', 'Early_Morning', 'zero', 'Morning']
# ['569', 'SpiceJet', 'SG-1063', 'Delhi', 'Evening', 'zero', 'Night']
# ['570', 'SpiceJet', 'SG-8169', 'Delhi', 'Evening', 'zero', 'Night']
# ['571', 'Vistara', 'UK-981', 'Delhi', 'Night', 'zero', 'Night']
# ['572', 'Vistara', 'UK-927', 'Delhi', 'Morning', 'zero', 'Morning']
# ['573', 'Vistara', 'UK-975', 'Delhi', 'Early_Morning', 'zero', 'Early_Morning']
# ['574', 'Vistara', 'UK-993', 'Delhi', 'Afternoon', 'zero', 'Afternoon']
# ['575', 'Vistara', 'UK-951', 'Delhi', 'Afternoon', 'zero', 'Evening']
# ['576', 'Vistara', 'UK-933', 'Delhi', 'Afternoon', 'zero', 'Evening']
# ['577', 'Vistara', 'UK-985', 'Delhi', 'Evening', 'zero', 'Night']
# ['578', 'Vistara', 'UK-953', 'Delhi', 'Night', 'zero', 'Night']
# ['579', 'Vistara', 'UK-943', 'Delhi', 'Early_Morning', 'zero', 'Morning']
# ['580', 'Vistara', 'UK-995', 'Delhi', 'Morning', 'zero', 'Afternoon']
# ['581', 'Vistara', 'UK-977', 'Delhi', 'Evening', 'zero', 'Night']
# ['582', 'Vistara', 'UK-963', 'Delhi', 'Morning', 'zero', 'Morning']
# ['583', 'Vistara', 'UK-945', 'Delhi', 'Morning', 'zero', 'Afternoon']
# ['584', 'Vistara', 'UK-941', 'Delhi', 'Evening', 'zero', 'Evening']
# ['585', 'Vistara', 'UK-955', 'Delhi', 'Evening', 'zero', 'Night']
# ['586', 'GO_FIRST', 'G8-334', 'Delhi', 'Early_Morning', 'zero', 'Morning']
# ['587', 'GO_FIRST', 'G8-336', 'Delhi', 'Afternoon', 'zero', 'Evening']
# ['588', 'GO_FIRST', 'G8-392', 'Delhi', 'Afternoon', 'zero', 'Evening']
# ['589', 'GO_FIRST', 'G8-346', 'Delhi', 'Evening', 'zero', 'Night']
# ['590', 'GO_FIRST', 'G8-338', 'Delhi', 'Morning', 'zero', 'Afternoon']
# ['591', 'GO_FIRST', 'G8-323', 'Delhi', 'Evening', 'zero', 'Night']
# ['592', 'Indigo', '6E-2054', 'Delhi', 'Early_Morning', 'zero', 'Morning']
# ['593', 'Indigo', '6E-5001', 'Delhi', 'Early_Morning', 'zero', 'Morning']
# ['594', 'Indigo', '6E-6202', 'Delhi', 'Morning', 'zero', 'Afternoon']
# ['595', 'Indigo', '6E-2046', 'Delhi', 'Evening', 'zero', 'Evening']
# ['596', 'Indigo', '6E-5041', 'Delhi', 'Evening', 'zero', 'Night']
# ['597', 'Indigo', '6.00E-218', 'Delhi', 'Morning', 'zero', 'Afternoon']
# ['598', 'Indigo', '6E-549', 'Delhi', 'Afternoon', 'zero', 'Evening']
# ['599', 'Indigo', '6E-6722', 'Delhi', 'Night', 'zero', 'Night']
# ['600', 'Indigo', '6E-6278', 'Delhi', 'Morning', 'zero', 'Morning']
# ['601', 'Indigo', '6E-5328', 'Delhi', 'Morning', 'zero', 'Morning']
# ['602', 'Air_India', 'AI-868', 'Delhi', 'Evening', 'zero', 'Evening']
# ['603', 'Air_India', 'AI-887', 'Delhi', 'Early_Morning', 'zero', 'Morning']
# ['604', 'Air_India', 'AI-665', 'Delhi', 'Early_Morning', 'zero', 'Morning']
# ['605', 'Air_India', 'AI-805', 'Delhi', 'Evening', 'zero', 'Night']
# ['606', 'Air_India', 'AI-678', 'Delhi', 'Morning', 'zero', 'Morning']
# ['607', 'Air_India', 'AI-624', 'Delhi', 'Evening', 'zero', 'Night']
# ['608', 'AirAsia', 'I5-721', 'Delhi', 'Night', 'one', 'Early_Morning']
# ['609', 'AirAsia', 'I5-773', 'Delhi', 'Evening', 'one', 'Early_Morning']
# ['610', 'GO_FIRST', 'G8-286', 'Delhi', 'Morning', 'one', 'Evening']
# ['611', 'GO_FIRST', 'G8-199', 'Delhi', 'Afternoon', 'two_or_more', 'Night']
# ['612', 'GO_FIRST', 'G8-191', 'Delhi', 'Morning', 'one', 'Evening']
# ['613', 'GO_FIRST', 'G8-266', 'Delhi', 'Early_Morning', 'one', 'Evening']
# ['614', 'GO_FIRST', 'G8-103', 'Delhi', 'Evening', 'one', 'Early_Morning']
# ['615', 'GO_FIRST', 'G8-101', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['616', 'GO_FIRST', 'G8-119', 'Delhi', 'Evening', 'one', 'Morning']
# ['617', 'GO_FIRST', 'G8-113', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['618', 'Air_India', 'AI-441', 'Delhi', 'Evening', 'one', 'Night']
# ['619', 'SpiceJet', 'SG-2976', 'Delhi', 'Evening', 'one', 'Night']
# ['620', 'SpiceJet', 'SG-2976', 'Delhi', 'Evening', 'one', 'Morning']
# ['621', 'SpiceJet', 'SG-8339', 'Delhi', 'Morning', 'one', 'Afternoon']
# ['622', 'SpiceJet', 'SG-2277', 'Delhi', 'Afternoon', 'one', 'Evening']
# ['623', 'AirAsia', 'I5-764', 'Delhi', 'Early_Morning', 'zero', 'Early_Morning']
# ['624', 'SpiceJet', 'SG-8483', 'Delhi', 'Evening', 'one', 'Early_Morning']
# ['625', 'Indigo', '6.00E-181', 'Delhi', 'Early_Morning', 'one', 'Morning']
# ['626', 'Indigo', '6E-5018', 'Delhi', 'Afternoon', 'one', 'Night']
# ['627', 'GO_FIRST', 'G8-330', 'Delhi', 'Night', 'zero', 'Night']
# ['628', 'Indigo', '6.00E-282', 'Delhi', 'Morning', 'two_or_more', 'Evening']
# ['629', 'Indigo', '6.00E-184', 'Delhi', 'Morning', 'one', 'Afternoon']
# ['630', 'Indigo', '6E-2168', 'Delhi', 'Evening', 'one', 'Night']
# ['631', 'Indigo', '6E-2193', 'Delhi', 'Afternoon', 'one', 'Night']
# ['632', 'Air_India', 'AI-481', 'Delhi', 'Morning', 'one', 'Night']
# ['633', 'Air_India', 'AI-435', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['634', 'Indigo', '6E-2193', 'Delhi', 'Afternoon', 'one', 'Evening']
# ['635', 'Indigo', '6E-2022', 'Delhi', 'Early_Morning', 'one', 'Evening']
# ['636', 'Vistara', 'UK-637', 'Delhi', 'Evening', 'one', 'Morning']
# ['637', 'Vistara', 'UK-706', 'Delhi', 'Afternoon', 'one', 'Morning']
# ['638', 'Air_India', 'AI-9643', 'Delhi', 'Evening', 'one', 'Afternoon']
# ['639', 'GO_FIRST', 'G8-719', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['640', 'GO_FIRST', 'G8-237', 'Delhi', 'Afternoon', 'one', 'Night']
# ['641', 'Air_India', 'AI-469', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['642', 'Air_India', 'AI-531', 'Delhi', 'Evening', 'one', 'Night']
# ['643', 'Air_India', 'AI-9843', 'Delhi', 'Early_Morning', 'one', 'Afternoon']
# ['644', 'Indigo', '6E-2102', 'Delhi', 'Early_Morning', 'one', 'Afternoon']
# ['645', 'Indigo', '6.00E-152', 'Delhi', 'Morning', 'one', 'Evening']
# ['646', 'GO_FIRST', 'G8-717', 'Delhi', 'Evening', 'one', 'Night']
# ['647', 'Vistara', 'UK-829', 'Delhi', 'Early_Morning', 'one', 'Afternoon']
# ['648', 'Vistara', 'UK-859', 'Delhi', 'Morning', 'one', 'Night']
# ['649', 'Vistara', 'UK-871', 'Delhi', 'Night', 'one', 'Morning']
# ['650', 'Vistara', 'UK-829', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['651', 'Vistara', 'UK-871', 'Delhi', 'Night', 'one', 'Afternoon']
# ['652', 'Vistara', 'UK-859', 'Delhi', 'Morning', 'one', 'Morning']
# ['653', 'Vistara', 'UK-871', 'Delhi', 'Night', 'one', 'Night']
# ['654', 'Vistara', 'UK-829', 'Delhi', 'Early_Morning', 'one', 'Morning']
# ['655', 'Vistara', 'UK-627', 'Delhi', 'Afternoon', 'one', 'Afternoon']
# ['656', 'Air_India', 'AI-469', 'Delhi', 'Early_Morning', 'one', 'Evening']
# ['657', 'Vistara', 'UK-899', 'Delhi', 'Afternoon', 'one', 'Night']
# ['658', 'Vistara', 'UK-899', 'Delhi', 'Afternoon', 'one', 'Morning']
# ['659', 'Vistara', 'UK-899', 'Delhi', 'Afternoon', 'one', 'Afternoon']
# ['660', 'Indigo', '6E-2154', 'Delhi', 'Morning', 'one', 'Afternoon']
# ['661', 'Vistara', 'UK-637', 'Delhi', 'Evening', 'one', 'Night']
# ['662', 'Vistara', 'UK-879', 'Delhi', 'Evening', 'one', 'Night']
# ['663', 'Vistara', 'UK-706', 'Delhi', 'Afternoon', 'one', 'Night']
# ['664', 'Vistara', 'UK-879', 'Delhi', 'Evening', 'one', 'Morning']
# ['665', 'SpiceJet', 'SG-3002', 'Delhi', 'Early_Morning', 'one', 'Morning']
# ['666', 'Air_India', 'AI-9887', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['667', 'Vistara', 'UK-683', 'Delhi', 'Afternoon', 'one', 'Afternoon']
# ['668', 'GO_FIRST', 'G8-1404', 'Delhi', 'Morning', 'one', 'Evening']
# ['669', 'GO_FIRST', 'G8-165', 'Delhi', 'Early_Morning', 'one', 'Afternoon']
# ['670', 'Air_India', 'AI-877', 'Delhi', 'Morning', 'one', 'Evening']
# ['671', 'Air_India', 'AI-473', 'Delhi', 'Evening', 'one', 'Evening']
# ['672', 'GO_FIRST', 'G8-286', 'Delhi', 'Morning', 'one', 'Evening']
# ['673', 'GO_FIRST', 'G8-1010', 'Delhi', 'Afternoon', 'one', 'Evening']
# ['674', 'Air_India', 'AI-9939', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['675', 'GO_FIRST', 'G8-213', 'Delhi', 'Morning', 'one', 'Evening']
# ['676', 'Air_India', 'AI-403', 'Delhi', 'Afternoon', 'one', 'Evening']
# ['677', 'Vistara', 'UK-811', 'Delhi', 'Early_Morning', 'one', 'Morning']
# ['678', 'Vistara', 'UK-817', 'Delhi', 'Evening', 'one', 'Night']
# ['679', 'Vistara', 'UK-813', 'Delhi', 'Evening', 'one', 'Night']
# ['680', 'Vistara', 'UK-819', 'Delhi', 'Afternoon', 'one', 'Night']
# ['681', 'Vistara', 'UK-819', 'Delhi', 'Afternoon', 'one', 'Night']
# ['682', 'Vistara', 'UK-817', 'Delhi', 'Evening', 'one', 'Night']
# ['683', 'Vistara', 'UK-819', 'Delhi', 'Afternoon', 'one', 'Night']
# ['684', 'Vistara', 'UK-819', 'Delhi', 'Afternoon', 'one', 'Night']
# ['685', 'Vistara', 'UK-801', 'Delhi', 'Morning', 'one', 'Night']
# ['686', 'Vistara', 'UK-807', 'Delhi', 'Night', 'one', 'Morning']
# ['687', 'Vistara', 'UK-801', 'Delhi', 'Morning', 'one', 'Night']
# ['688', 'Vistara', 'UK-815', 'Delhi', 'Morning', 'one', 'Night']
# ['689', 'Vistara', 'UK-809', 'Delhi', 'Evening', 'one', 'Morning']
# ['690', 'Air_India', 'AI-479', 'Delhi', 'Night', 'one', 'Afternoon']
# ['691', 'GO_FIRST', 'G8-286', 'Delhi', 'Morning', 'one', 'Night']
# ['692', 'Air_India', 'AI-504', 'Delhi', 'Night', 'one', 'Morning']
# ...
# ['8560', 'AirAsia', 'I5-482', 'Delhi', 'Evening', 'zero', 'Night']
# ['8561', 'Indigo', '6E-6261', 'Delhi', 'Evening', 'zero', 'Night']
# ['8562', 'GO_FIRST', 'G8-330', 'Delhi', 'Night', 'zero', 'Night']
# ['8563', 'Indigo', '6E-6278', 'Delhi', 'Morning', 'zero', 'Morning']
# ['8564', 'GO_FIRST', 'G8-338', 'Delhi', 'Morning', 'zero', 'Afternoon']
# ['8565', 'Indigo', '6.00E-218', 'Delhi', 'Morning', 'zero', 'Afternoon']
# ['8566', 'GO_FIRST', 'G8-323', 'Delhi', 'Evening', 'zero', 'Night']
# ['8567', 'Indigo', '6E-2081', 'Delhi', 'Early_Morning', 'zero', 'Early_Morning']
# ['8568', 'AirAsia', 'I5-773', 'Delhi', 'Evening', 'one', 'Late_Night']
# ['8569', 'AirAsia', 'I5-721', 'Delhi', 'Night', 'one', 'Early_Morning']
# ['8570', 'AirAsia', 'I5-1529', 'Delhi', 'Morning', 'one', 'Night']
# ['8571', 'AirAsia', 'I5-773', 'Delhi', 'Evening', 'one', 'Early_Morning']
# ['8572', 'AirAsia', 'I5-740', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['8573', 'AirAsia', 'I5-798', 'Delhi', 'Afternoon', 'one', 'Late_Night']
# ['8574', 'AirAsia', 'I5-788', 'Delhi', 'Night', 'one', 'Afternoon']
# ['8575', 'AirAsia', 'I5-1529', 'Delhi', 'Morning', 'one', 'Late_Night']
# ['8576', 'Indigo', '6E-2193', 'Delhi', 'Afternoon', 'one', 'Evening']
# ['8577', 'Indigo', '6.00E-184', 'Delhi', 'Morning', 'one', 'Afternoon']
# ['8578', 'Indigo', '6E-2102', 'Delhi', 'Early_Morning', 'one', 'Afternoon']
# ['8579', 'Indigo', '6E-2092', 'Delhi', 'Evening', 'one', 'Night']
# ['8580', 'Indigo', '6E-2083', 'Delhi', 'Early_Morning', 'one', 'Morning']
# ['8581', 'Indigo', '6E-2373', 'Delhi', 'Afternoon', 'one', 'Evening']
# ['8582', 'Indigo', '6E-2013', 'Delhi', 'Early_Morning', 'one', 'Morning']
# ['8583', 'Indigo', '6E-2097', 'Delhi', 'Early_Morning', 'one', 'Afternoon']
# ['8584', 'Indigo', '6.00E-152', 'Delhi', 'Morning', 'one', 'Evening']
# ['8585', 'Indigo', '6E-607', 'Delhi', 'Night', 'one', 'Early_Morning']
# ['8586', 'Indigo', '6E-2338', 'Delhi', 'Afternoon', 'one', 'Night']
# ['8587', 'Indigo', '6E-2193', 'Delhi', 'Afternoon', 'one', 'Night']
# ['8588', 'Indigo', '6E-7403', 'Delhi', 'Early_Morning', 'one', 'Evening']
# ['8589', 'Indigo', '6E-5018', 'Delhi', 'Afternoon', 'one', 'Night']
# ['8590', 'Indigo', '6E-369', 'Delhi', 'Night', 'one', 'Morning']
# ['8591', 'SpiceJet', 'SG-8709', 'Delhi', 'Evening', 'zero', 'Night']
# ['8592', 'SpiceJet', 'SG-8803', 'Delhi', 'Early_Morning', 'zero', 'Morning']
# ['8593', 'SpiceJet', 'SG-8169', 'Delhi', 'Evening', 'zero', 'Night']
# ['8594', 'Air_India', 'AI-868', 'Delhi', 'Evening', 'zero', 'Evening']
# ['8595', 'Air_India', 'AI-887', 'Delhi', 'Early_Morning', 'zero', 'Morning']
# ['8596', 'Air_India', 'AI-665', 'Delhi', 'Early_Morning', 'zero', 'Morning']
# ['8597', 'Air_India', 'AI-865', 'Delhi', 'Morning', 'zero', 'Afternoon']
# ['8598', 'Air_India', 'AI-805', 'Delhi', 'Evening', 'zero', 'Night']
# ['8599', 'Air_India', 'AI-678', 'Delhi', 'Morning', 'zero', 'Morning']
# ['8600', 'Air_India', 'AI-624', 'Delhi', 'Evening', 'zero', 'Night']
# ['8601', 'Air_India', 'AI-636', 'Delhi', 'Afternoon', 'one', 'Evening']
# ['8602', 'Air_India', 'AI-441', 'Delhi', 'Evening', 'one', 'Night']
# ['8603', 'SpiceJet', 'SG-8157', 'Delhi', 'Early_Morning', 'zero', 'Morning']
# ['8604', 'Indigo', '6E-549', 'Delhi', 'Afternoon', 'zero', 'Evening']
# ['8605', 'Indigo', '6E-5328', 'Delhi', 'Morning', 'zero', 'Morning']
# ['8606', 'Vistara', 'UK-943', 'Delhi', 'Early_Morning', 'zero', 'Morning']
# ['8607', 'Vistara', 'UK-977', 'Delhi', 'Evening', 'zero', 'Night']
# ['8608', 'Vistara', 'UK-963', 'Delhi', 'Morning', 'zero', 'Morning']
# ['8609', 'Vistara', 'UK-941', 'Delhi', 'Evening', 'zero', 'Evening']
# ['8610', 'Vistara', 'UK-955', 'Delhi', 'Evening', 'zero', 'Night']
# ['8611', 'Indigo', '6E-2046', 'Delhi', 'Evening', 'zero', 'Evening']
# ['8612', 'Indigo', '6E-5041', 'Delhi', 'Evening', 'zero', 'Night']
# ['8613', 'Indigo', '6E-573', 'Delhi', 'Afternoon', 'zero', 'Evening']
# ['8614', 'Air_India', 'AI-9843', 'Delhi', 'Early_Morning', 'one', 'Afternoon']
# ['8615', 'Air_India', 'AI-9643', 'Delhi', 'Evening', 'one', 'Afternoon']
# ['8616', 'GO_FIRST', 'G8-717', 'Delhi', 'Evening', 'one', 'Night']
# ['8617', 'GO_FIRST', 'G8-713', 'Delhi', 'Evening', 'one', 'Late_Night']
# ['8618', 'GO_FIRST', 'G8-717', 'Delhi', 'Evening', 'one', 'Late_Night']
# ['8619', 'SpiceJet', 'SG-2976', 'Delhi', 'Evening', 'one', 'Night']
# ['8620', 'SpiceJet', 'SG-2976', 'Delhi', 'Evening', 'one', 'Morning']
# ['8621', 'Air_India', 'AI-9887', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['8622', 'Indigo', '6E-2042', 'Delhi', 'Night', 'one', 'Early_Morning']
# ['8623', 'Indigo', '6.00E-181', 'Delhi', 'Early_Morning', 'one', 'Morning']
# ['8624', 'Indigo', '6E-607', 'Delhi', 'Night', 'one', 'Morning']
# ['8625', 'Indigo', '6E-2168', 'Delhi', 'Evening', 'one', 'Night']
# ['8626', 'AirAsia', 'I5-747', 'Delhi', 'Evening', 'one', 'Late_Night']
# ['8627', 'AirAsia', 'I5-747', 'Delhi', 'Evening', 'one', 'Early_Morning']
# ['8628', 'Vistara', 'UK-627', 'Delhi', 'Afternoon', 'one', 'Afternoon']
# ['8629', 'Air_India', 'AI-544', 'Delhi', 'Evening', 'one', 'Night']
# ['8630', 'Air_India', 'AI-542', 'Delhi', 'Morning', 'one', 'Night']
# ['8631', 'Air_India', 'AI-560', 'Delhi', 'Morning', 'one', 'Night']
# ['8632', 'Air_India', 'AI-839', 'Delhi', 'Night', 'one', 'Night']
# ['8633', 'Air_India', 'AI-429', 'Delhi', 'Morning', 'one', 'Evening']
# ['8634', 'Air_India', 'AI-439', 'Delhi', 'Early_Morning', 'one', 'Evening']
# ['8635', 'Air_India', 'AI-540', 'Delhi', 'Night', 'one', 'Morning']
# ['8636', 'Air_India', 'AI-537', 'Delhi', 'Evening', 'one', 'Morning']
# ['8637', 'Air_India', 'AI-540', 'Delhi', 'Night', 'one', 'Evening']
# ['8638', 'Air_India', 'AI-429', 'Delhi', 'Morning', 'one', 'Morning']
# ['8639', 'Air_India', 'AI-439', 'Delhi', 'Early_Morning', 'one', 'Morning']
# ['8640', 'Air_India', 'AI-537', 'Delhi', 'Evening', 'one', 'Evening']
# ['8641', 'SpiceJet', 'SG-339', 'Delhi', 'Afternoon', 'one', 'Afternoon']
# ['8642', 'Vistara', 'UK-637', 'Delhi', 'Evening', 'one', 'Night']
# ['8643', 'Vistara', 'UK-706', 'Delhi', 'Afternoon', 'one', 'Night']
# ['8644', 'Vistara', 'UK-637', 'Delhi', 'Evening', 'one', 'Morning']
# ['8645', 'Vistara', 'UK-706', 'Delhi', 'Afternoon', 'one', 'Morning']
# ['8646', 'Air_India', 'AI-471', 'Delhi', 'Afternoon', 'one', 'Evening']
# ['8647', 'Air_India', 'AI-481', 'Delhi', 'Morning', 'one', 'Night']
# ['8648', 'SpiceJet', 'SG-3002', 'Delhi', 'Early_Morning', 'one', 'Morning']
# ['8649', 'Indigo', '6E-926', 'Delhi', 'Evening', 'one', 'Night']
# ['8650', 'Air_India', 'AI-469', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['8651', 'Air_India', 'AI-531', 'Delhi', 'Evening', 'one', 'Night']
# ['8652', 'Vistara', 'UK-833', 'Delhi', 'Early_Morning', 'one', 'Afternoon']
# ['8653', 'Vistara', 'UK-833', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['8654', 'Vistara', 'UK-683', 'Delhi', 'Afternoon', 'one', 'Afternoon']
# ['8655', 'Indigo', '6E-6202', 'Delhi', 'Morning', 'zero', 'Afternoon']
# ['8656', 'SpiceJet', 'SG-2277', 'Delhi', 'Afternoon', 'one', 'Evening']
# ['8657', 'Vistara', 'UK-673', 'Delhi', 'Afternoon', 'one', 'Evening']
# ['8658', 'Vistara', 'UK-839', 'Delhi', 'Afternoon', 'one', 'Night']
# ['8659', 'Vistara', 'UK-835', 'Delhi', 'Evening', 'one', 'Morning']
# ['8660', 'Vistara', 'UK-837', 'Delhi', 'Evening', 'one', 'Morning']
# ['8661', 'Vistara', 'UK-835', 'Delhi', 'Evening', 'one', 'Morning']
# ['8662', 'Vistara', 'UK-837', 'Delhi', 'Evening', 'one', 'Morning']
# ['8663', 'Vistara', 'UK-835', 'Delhi', 'Evening', 'one', 'Afternoon']
# ['8664', 'AirAsia', 'I5-784', 'Delhi', 'Evening', 'one', 'Late_Night']
# ['8665', 'AirAsia', 'I5-784', 'Delhi', 'Evening', 'one', 'Early_Morning']
# ['8666', 'Vistara', 'UK-879', 'Delhi', 'Evening', 'one', 'Night']
# ['8667', 'Vistara', 'UK-829', 'Delhi', 'Early_Morning', 'one', 'Afternoon']
# ['8668', 'Vistara', 'UK-899', 'Delhi', 'Afternoon', 'one', 'Night']
# ['8669', 'Vistara', 'UK-859', 'Delhi', 'Morning', 'one', 'Night']
# ['8670', 'Vistara', 'UK-871', 'Delhi', 'Night', 'one', 'Morning']
# ['8671', 'Vistara', 'UK-829', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['8672', 'Vistara', 'UK-879', 'Delhi', 'Evening', 'one', 'Morning']
# ['8673', 'Vistara', 'UK-871', 'Delhi', 'Night', 'one', 'Afternoon']
# ['8674', 'Vistara', 'UK-899', 'Delhi', 'Afternoon', 'one', 'Morning']
# ['8675', 'Vistara', 'UK-879', 'Delhi', 'Evening', 'one', 'Afternoon']
# ['8676', 'Air_India', 'AI-473', 'Delhi', 'Evening', 'one', 'Evening']
# ['8677', 'GO_FIRST', 'G8-211', 'Delhi', 'Morning', 'one', 'Afternoon']
# ['8678', 'GO_FIRST', 'G8-2509', 'Delhi', 'Early_Morning', 'one', 'Afternoon']
# ['8679', 'GO_FIRST', 'G8-211', 'Delhi', 'Morning', 'one', 'Night']
# ['8680', 'GO_FIRST', 'G8-2609', 'Delhi', 'Night', 'one', 'Morning']
# ['8681', 'GO_FIRST', 'G8-1404', 'Delhi', 'Morning', 'one', 'Evening']
# ['8682', 'AirAsia', 'I5-775', 'Delhi', 'Afternoon', 'one', 'Late_Night']
# ['8683', 'Air_India', 'AI-411', 'Delhi', 'Early_Morning', 'one', 'Afternoon']
# ['8684', 'Air_India', 'AI-401', 'Delhi', 'Early_Morning', 'one', 'Evening']
# ['8685', 'Air_India', 'AI-877', 'Delhi', 'Morning', 'one', 'Evening']
# ['8686', 'Air_India', 'AI-465', 'Delhi', 'Evening', 'one', 'Night']
# ['8687', 'Air_India', 'AI-512', 'Delhi', 'Afternoon', 'one', 'Night']
# ['8688', 'Air_India', 'AI-883', 'Delhi', 'Night', 'one', 'Morning']
# ['8689', 'Air_India', 'AI-883', 'Delhi', 'Night', 'one', 'Evening']
# ['8690', 'Vistara', 'UK-855', 'Delhi', 'Evening', 'one', 'Afternoon']
# ['8691', 'GO_FIRST', 'G8-7553', 'Delhi', 'Afternoon', 'one', 'Night']
# ['8692', 'GO_FIRST', 'G8-237', 'Delhi', 'Afternoon', 'one', 'Night']
# ['8693', 'Air_India', 'AI-767', 'Delhi', 'Afternoon', 'one', 'Night']
# ['8694', 'Air_India', 'AI-401', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['8695', 'Air_India', 'AI-502', 'Delhi', 'Afternoon', 'one', 'Night']
# ['8696', 'SpiceJet', 'SG-8483', 'Delhi', 'Evening', 'one', 'Early_Morning']
# ['8697', 'Air_India', 'AI-803', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['8698', 'Air_India', 'AI-502', 'Delhi', 'Afternoon', 'one', 'Morning']
# ['8699', 'GO_FIRST', 'G8-194', 'Delhi', 'Night', 'one', 'Early_Morning']
# ['8700', 'Air_India', 'AI-762', 'Delhi', 'Night', 'one', 'Afternoon']
# ['8701', 'Air_India', 'AI-764', 'Delhi', 'Evening', 'one', 'Afternoon']
# ['8702', 'Air_India', 'AI-483', 'Delhi', 'Evening', 'one', 'Evening']
# ['8703', 'Air_India', 'AI-409', 'Delhi', 'Morning', 'one', 'Evening']
# ['8704', 'Vistara', 'UK-811', 'Delhi', 'Early_Morning', 'one', 'Morning']
# ['8705', 'Vistara', 'UK-817', 'Delhi', 'Evening', 'one', 'Night']
# ['8706', 'Vistara', 'UK-813', 'Delhi', 'Evening', 'one', 'Night']
# ['8707', 'Vistara', 'UK-819', 'Delhi', 'Afternoon', 'one', 'Night']
# ['8708', 'Vistara', 'UK-819', 'Delhi', 'Afternoon', 'one', 'Night']
# ['8709', 'Vistara', 'UK-817', 'Delhi', 'Evening', 'one', 'Night']
# ['8710', 'Vistara', 'UK-819', 'Delhi', 'Afternoon', 'one', 'Night']
# ['8711', 'Vistara', 'UK-819', 'Delhi', 'Afternoon', 'one', 'Night']
# ['8712', 'Vistara', 'UK-801', 'Delhi', 'Morning', 'one', 'Night']
# ['8713', 'Vistara', 'UK-807', 'Delhi', 'Night', 'one', 'Morning']
# ['8714', 'Vistara', 'UK-801', 'Delhi', 'Morning', 'one', 'Night']
# ['8715', 'GO_FIRST', 'G8-2403', 'Delhi', 'Morning', 'one', 'Evening']
# ['8716', 'GO_FIRST', 'G8-2401', 'Delhi', 'Morning', 'one', 'Evening']
# ['8717', 'GO_FIRST', 'G8-113', 'Delhi', 'Early_Morning', 'one', 'Morning']
# ['8718', 'Air_India', 'AI-506', 'Delhi', 'Morning', 'one', 'Night']
# ['8719', 'Air_India', 'AI-807', 'Delhi', 'Evening', 'one', 'Morning']
# ['8720', 'Air_India', 'AI-506', 'Delhi', 'Morning', 'one', 'Morning']
# ['8721', 'Air_India', 'AI-451', 'Delhi', 'Afternoon', 'one', 'Night']
# ['8722', 'Air_India', 'AI-9609', 'Delhi', 'Evening', 'one', 'Afternoon']
# ['8723', 'GO_FIRST', 'G8-119', 'Delhi', 'Evening', 'one', 'Early_Morning']
# ['8724', 'Air_India', 'AI-885', 'Delhi', 'Morning', 'one', 'Evening']
# ['8725', 'Air_India', 'AI-406', 'Delhi', 'Morning', 'one', 'Afternoon']
# ['8726', 'Air_India', 'AI-885', 'Delhi', 'Morning', 'one', 'Night']
# ['8727', 'Air_India', 'AI-453', 'Delhi', 'Early_Morning', 'one', 'Afternoon']
# ['8728', 'Air_India', 'AI-479', 'Delhi', 'Night', 'one', 'Afternoon']
# ['8729', 'Indigo', '6E-6722', 'Delhi', 'Night', 'zero', 'Night']
# ['8730', 'Vistara', 'UK-705', 'Delhi', 'Early_Morning', 'one', 'Afternoon']
# ['8731', 'Vistara', 'UK-707', 'Delhi', 'Evening', 'one', 'Night']
# ['8732', 'Vistara', 'UK-747', 'Delhi', 'Early_Morning', 'one', 'Afternoon']
# ['8733', 'Vistara', 'UK-737', 'Delhi', 'Afternoon', 'one', 'Night']
# ['8734', 'Vistara', 'UK-705', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['8735', 'Vistara', 'UK-747', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['8736', 'Vistara', 'UK-705', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['8737', 'Vistara', 'UK-727', 'Delhi', 'Night', 'one', 'Afternoon']
# ['8738', 'Vistara', 'UK-747', 'Delhi', 'Early_Morning', 'one', 'Night']
# ['8739', 'GO_FIRST', 'G8-7541', 'Delhi', 'Early_Morning', 'one', 'Afternoon']
# ['8740', 'GO_FIRST', 'G8-165', 'Delhi', 'Early_Morning', 'one', 'Afternoon']
# ['8741', 'GO_FIRST', 'G8-101', 'Delhi', 'Early_Morning', 'one', 'Afternoon']
# ['8742', 'GO_FIRST', 'G8-103', 'Delhi', 'Evening', 'one', 'Early_Morning']
# ['8743', 'Air_India', 'AI-801', 'Delhi', 'Evening', 'one', 'Night']
# ['8744', 'Air_India', 'AI-9017', 'Delhi', 'Morning', 'one', 'Afternoon']
# ['8745', 'GO_FIRST', 'G8-286', 'Delhi', 'Morning', 'one', 'Evening']
# ['8746', 'GO_FIRST', 'G8-286', 'Delhi', 'Morning', 'one', 'Evening']
# ['8747', 'GO_FIRST', 'G8-191', 'Delhi', 'Morning', 'one', 'Evening']
# ['8748', 'GO_FIRST', 'G8-266', 'Delhi', 'Early_Morning', 'one', 'Evening']
# ['8749', 'GO_FIRST', 'G8-213', 'Delhi', 'Morning', 'one', 'Evening']
# ['8750', 'Vistara', 'UK-975', 'Delhi', 'Early_Morning', 'zero', 'Early_Morning']
# ['8751', 'Vistara', 'UK-953', 'Delhi', 'Night', 'zero', 'Night']
# ['8752', 'Vistara', 'UK-981', 'Delhi', 'Night', 'zero', 'Night']
# ['8753', 'Vistara', 'UK-927', 'Delhi', 'Morning', 'zero', 'Morning']
# ['8754', 'Vistara', 'UK-993', 'Delhi', 'Afternoon', 'zero', 'Afternoon']
# ['8755', 'Vistara', 'UK-951', 'Delhi', 'Afternoon', 'zero', 'Evening']
# ['8756', 'Vistara', 'UK-933', 'Delhi', 'Afternoon', 'zero', 'Evening']
# ['8757', 'Vistara', 'UK-985', 'Delhi', 'Evening', 'zero', 'Night']
# ['8758', 'Vistara', 'UK-995', 'Delhi', 'Morning', 'zero', 'Afternoon']
# ['8759', 'Vistara', 'UK-945', 'Delhi', 'Morning', 'zero', 'Afternoon']
# ['8760', 'GO_FIRST', 'G8-7533', 'Delhi', 'Afternoon', 'zero', 'Afternoon']
# ['8761', 'GO_FIRST', 'G8-7534', 'Delhi', 'Afternoon', 'zero', 'Evening']
# ['8762', 'GO_FIRST', 'G8-7535', 'Delhi', 'Evening', 'zero', 'Evening']
# ['8763', 'Indigo', '6.00E-171', 'Delhi', 'Late_Night', 'zero', 'Early_Morning']
# ['8764', 'AirAsia', 'I5-764', 'Delhi', 'Early_Morning', 'zero', 'Early_Morning']
# ['8765', 'Indigo', '6E-2054', 'Delhi', 'Early_Morning', 'zero', 'Morning']
# ['8766', 'GO_FIRST', 'G8-530', 'Delhi', 'Early_Morning', 'zero', 'Morning']
# ['8767', 'Indigo', '6E-5001', 'Delhi', 'Early_Morning', 'zero', 'Morning']
# ['8768', 'GO_FIRST', 'G8-334', 'Delhi', 'Early_Morning', 'zero', 'Morning']
# ['8769', 'Indigo', '6E-5329', 'Delhi', 'Morning', 'zero', 'Morning']
# ['8770', 'GO_FIRST', 'G8-354', 'Delhi', 'Night', 'zero', 'Late_Night']
# ['8771', 'Indigo', '6E-2137', 'Delhi', 'Night', 'zero', 'Late_Night']
# ['8772', 'GO_FIRST', 'G8-2501', 'Delhi', 'Late_Night', 'zero', 'Early_Morning']
# ['8773', 'GO_FIRST', 'G8-336', 'Delhi', 'Afternoon', 'zero', 'Evening']
# ['8774', 'GO_FIRST', 'G8-392', 'Delhi', 'Afternoon', 'zero', 'Evening']
# ['8775', 'GO_FIRST', 'G8-346', 'Delhi', 'Evening', 'zero', 'Night']
# ['8776', 'AirAsia', 'I5-482', 'Delhi', 'Evening', 'zero', 'Night']
# ['8777', 'Indigo', '6E-6261', 'Delhi', 'Evening', 'zero', 'Night']
# ['8778', 'GO_FIRST', 'G8-330', 'Delhi', 'Night', 'zero', 'Night']
# ['8779', 'Indigo', '6E-6278', 'Delhi', 'Morning', 'zero', 'Morning']
# ['8780', 'GO_FIRST', 'G8-338', 'Delhi', 'Morning', 'zero', 'Afternoon']
# ['8781', 'Indigo', '6.00E-218', 'Delhi', 'Morning', 'zero', 'Afternoon']
# ['8782', 'GO_FIRST', 'G8-323', 'Delhi', 'Evening', 'zero', 'Night']
# ['8783', 'Indigo', '6E-2081', 'Delhi', 'Early_Morning', 'zero', 'Early_Morning']
# ['8784', 'AirAsia', 'I5-773', 'Delhi', 'Evening', 'one', 'Late_Night']
